# %% [markdown]
# <a href="https://colab.research.google.com/github/taskswithcode/mae/blob/main/TWCMAE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Notebook to reproduce results of latent-diffusion**

# %% [markdown]
# ## 1. Download the tar file containing original repository, environment snapshot, and required models

# %%
# !gdown 1wdiXVpTkVcW5MhB8_5JtqpIPKWA2wUTy

# %%
# !mv s3cfg /root/.s3cfg

# %%
# !apt-get install s3cmd

# %%
# !s3cmd ls s3://repos/mae.tar
# Out:
# 2022-08-06 05:21 5019896104   s3://repos/mae.tar

# %%
# !s3cmd get s3://repos/mae.tar
# Out:
# download: 's3://repos/mae.tar' -> './mae.tar'  [1 of 1]
# download: 's3://repos/mae.tar' -> './mae.tar'  [1 of 1]
# download: 's3://repos/mae.tar' -> './mae.tar'  [1 of 1]
#  5019896104 of 5019896104   100% in  162s    29.47 MB/s  done

# %% [markdown]
# ## 2. Extract from the tar file and change working directory

# %%
# !tar xvzf mae.tar

# %%
# !rm mae.tar

# %%
cd mae

# %% [markdown]
# ## 3. Set up local environment

# %%
from matplotlib.pyplot import imshow
import numpy as np
from PIL import Image
from IPython.display import display # to display imag

# %% [markdown]
# ## 4. Run sample tests within the environment, starting with replicating tests from original repository

# %%
# !ls -ltr

# %%
!(source conda_envs/bin/activate; python twc_main.py -input twc_samples/imagenet_fox.jpg -output test_output )

# %%
pil_im = Image.open('test_output_1.png')
display(pil_im)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2400x2400 at 0x7FB901BC5D50>

# %%
pil_im = Image.open('test_output_1.png')
display(pil_im)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2400x2400 at 0x7FB900B5B650>
