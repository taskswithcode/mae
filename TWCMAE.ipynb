# %% [markdown]
# <a href="https://colab.research.google.com/github/taskswithcode/mae/blob/main/TWCMAE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Notebook to reproduce results of latent-diffusion**

# %% [markdown]
# ## 1. Check GPU is available

# %%
# !nvidia-smi
# Out:
# Fri Jul 29 19:41:38 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# ## 2. Download the tar file containing original repository, environment snapshot, and required models

# %%
# !gdown 1wdiXVpTkVcW5MhB8_5JtqpIPKWA2wUTy

# %%
# !mv s3cfg /root/.s3cfg

# %%
# !apt-get install s3cmd

# %%
# !s3cmd ls s3://repos

# %%
# !s3cmd get s3://repos/latent-diffusion.tar

# %% [markdown]
# ## 3. Extract from the tar file and change working directory

# %%
# !tar xvzf latent-diffusion.tar

# %%
# !rm latent-diffusion.tar

# %%
cd latent-diffusion
# Out:
# /content/latent-diffusion

# %% [markdown]
# ## 4. Set up local environment

# %%
# !./twc_setup.sh

# %%
from matplotlib.pyplot import imshow
import numpy as np
from PIL import Image
from IPython.display import display # to display imag

# %% [markdown]
# ## 5a. Run sample tests within the environment, starting with replicating tests from original repository

# %%
!(source conda_envs/bin/activate; python twc_codebook_examine.py -input twc_samples/sample1.png )

# %%
# !head -10 indices_sample1.txt
# Out:
# 6769
# 5271
# 1541
# 6692
# 6247
# 3742
# 6812
# 127
# 6084
# 4058

# %%
!(source conda_envs/bin/activate; python twc_codebook_examine.py -input indices_sample1.txt -output recons1.png )

# %%
pil_im = Image.open('twc_samples/sample1.png')
display(pil_im)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=384x384 at 0x7F8F8E541A10>

# %%
pil_im = Image.open('recons1.png')
display(pil_im)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=384x384 at 0x7F8F91E8A6D0>

# %%
!(source conda_envs/bin/activate; python twc_codebook_examine.py -input twc_samples/sample2.png )

# %%
# !head -10 indices_sample2.txt
# Out:
# 2291
# 3225
# 4689
# 5547
# 877
# 5512
# 4781
# 617
# 604
# 7074

# %%
# !wc -l indices_sample2.txt
# Out:
# 9216 indices_sample2.txt

# %%
!(source conda_envs/bin/activate; python twc_codebook_examine.py -input indices_sample2.txt -output recons2.png )

# %%
pil_im = Image.open('twc_samples/sample2.png')
display(pil_im)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=384x384 at 0x7F8F8D4FA510>

# %%
pil_im = Image.open('recons2.png')
display(pil_im)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=384x384 at 0x7F8F8D4E2E10>

# %%
!(source conda_envs/bin/activate; python twc_codebook_examine.py -input twc_samples/sample3.png )
# Out:
# Enter option:
# 	(1) Examine codebook - dump codebook vectors as a numpy file
# 	(2) Visualize each codebook values. Write images into out dir
# 	(3) Output codebook indices for an input image
# 	(4) Generate image using  codebook indices
# 	(5) Generate using custom codebook indices (index corrected by 1 for ease)
# 	(6) Output codebook indices for all images in input dir
# 	(0) Quit
# 3
# Working with z of shape (1, 3, 64, 64) = 12288 dimensions.
# loaded pretrained LPIPS loss from taming/modules/autoencoder/lpips/vgg.pth
# VQLPIPSWithDiscriminator running with hinge loss.
# Restored from models/first_stage_models/vq-f4-noattn/model.ckpt
# Enter option:
# 	(1) Examine codebook - dump codebook vectors as a numpy file
# 	(2) Visualize each codebook values. Write images into out dir
# 	(3) Output codebook indices for an input image
# 	(4) Generate image using  codebook indices
# 	(5) Generate using custom codebook indices (index corrected by 1 for ease)
# ...

# %%
!(source conda_envs/bin/activate; python twc_codebook_examine.py -input indices_sample3.txt -output recons3.png )

# %%
pil_im = Image.open('twc_samples/sample3.png')
display(pil_im)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=384x384 at 0x7F8F8E52CCD0>

# %%
pil_im = Image.open('recons3.png')
display(pil_im)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=384x384 at 0x7F8F8D4F0AD0>
